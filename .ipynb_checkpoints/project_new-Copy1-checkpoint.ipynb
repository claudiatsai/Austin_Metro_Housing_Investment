# %% [markdown]
# # Time Series Zillow Research

# %% [markdown]
# # Business Problem

# %% [markdown]
# Our client is an investor who is looking for buying in Austin, TX. We will build a model to help the client make the decision. The reason that the client chose Austin, TX is because the rapidly expanding economy.

# %% [markdown]
# ## Obtaining Data

# %% [markdown]
# ### Import the Libraries & Load Data

# %%
# importing relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

#from pmdarima.arima import auto_arima
#from pyramid.arima.utils import ndiffs
from sklearn.metrics import mean_squared_error
import math
import warnings
warnings.filterwarnings('ignore')

import itertools
from collections import Counter



import seaborn as sns

from statsmodels.tsa.arima.model import  ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMAResults

# %matplotlib inline
from matplotlib.pylab import rcParams

# %%
# Loading the data
df = pd.read_csv('zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df.dtypes
# Out:
# RegionID       int64
# RegionName     int64
# City          object
# State         object
# Metro         object
#                ...
# 2017-12        int64
# 2018-01        int64
# 2018-02        int64
# 2018-03        int64
# 2018-04        int64
# Length: 272, dtype: object

# %%
df.iloc[:,0:5].nunique()
# Out:
# RegionID      14723
# RegionName    14723
# City           7554
# State            51
# Metro           701
# dtype: int64

# %%
# The RegionID and RegionName looks similar but RegionName is the actual zipcode.
# Rename colunmn " RegionName" to "Zipcode"

df.rename({'RegionName': 'Zipcode'}, axis='columns', inplace=True)
df.head()
# Out:
#    RegionID  Zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654    60657   Chicago    IL            Chicago       Cook         1
# 1     90668    75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982    77494      Katy    TX            Houston     Harris         3
# 3     84616    60614   Chicago    IL            Chicago       Cook         4
# 4     93144    79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 0  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800  1009600
# 1  235700.0  236900.0  236700.0  ...   308000   310000   312500   314100
# 2  210400.0  212200.0  212200.0  ...   321000   320600   320200   320400
# 3  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400  1291500
# 4   77300.0   77300.0   77300.0  ...   119100   119400   120000   120300
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1013300  1018700  1024400  1030700  1033800  1030600
# 1   315000   316600   318100   319600   321100   321800
# 2   320800   321200   321200   323000   326900   329900
# 3  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
# Narrow down the data to the desired state
tx = df.loc[df['State']=='TX']
tx.head()
# Out:
#    RegionID  Zipcode      City State              Metro CountyName  SizeRank  \
# 1     90668    75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982    77494      Katy    TX            Houston     Harris         3
# 4     93144    79936   El Paso    TX            El Paso    El Paso         5
# 5     91733    77084   Houston    TX            Houston     Harris         6
# 8     91940    77449      Katy    TX            Houston     Harris         9
#
#     1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 1  235700.0  236900.0  236700.0  ...   308000   310000   312500   314100
# 2  210400.0  212200.0  212200.0  ...   321000   320600   320200   320400
# 4   77300.0   77300.0   77300.0  ...   119100   119400   120000   120300
# 5   95000.0   95200.0   95400.0  ...   157900   158700   160200   161900
# 8   95400.0   95600.0   95800.0  ...   166800   167400   168400   169600
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1   315000   316600   318100   319600   321100   321800
# 2   320800   321200   321200   323000   326900   329900
# 4   120300   120300   120300   120500   121000   121500
# 5   162800   162800   162800   162900   163500   164300
# 8   170900   172300   173300   174200   175400   176200
#
# [5 rows x 272 columns]

# %%
# Find metro area in TX
tx.Metro.value_counts()
# Out:
# Dallas-Fort Worth    217
# Houston              187
# San Antonio           78
# Austin                73
# Corpus Christi        22
# Beaumont              21
# El Paso               21
# Killeen               19
# Waco                  16
# Lubbock               15
# Tyler                 15
# Wichita Falls         12
# College Station       11
# Amarillo              11
# Longview              11
# McAllen               11
# Athens                11
# Abilene               11
# Brownsville           10
# Texarkana              7
# Odessa                 6
# Marshall               6
# Victoria               5
# San Angelo             5
# Huntsville             4
# Midland                4
# El Campo               4
# Laredo                 4
# Port Lavaca            3
# Brownwood              3
# Nacogdoches            3
# Palestine              3
# Bay City               3
# Brenham                3
# Corsicana              3
# Jacksonville           2
# Levelland              2
# Paris                  2
# Plainview              2
# Dumas                  2
# Kerrville              2
# Mineral Wells          2
# Rio Grande City        2
# Gainesville            2
# Lufkin                 2
# Lamesa                 1
# Vernon                 1
# Sweetwater             1
# Hereford               1
# Del Rio                1
# Uvalde                 1
# Eagle Pass             1
# Pampa                  1
# Beeville               1
# Stephenville           1
# Kingsville             1
# Mount Pleasant         1
# Fredericksburg         1
# Alice                  1
# Borger                 1
# Name: Metro, dtype: int64

# %%
# Narrow down the data to specific metro "Austin"
tx_aus = tx.loc[tx['City']=='Austin']
tx_aus.head()
# Out:
#      RegionID  Zipcode    City State   Metro CountyName  SizeRank   1996-04  \
# 66      92617    78704  Austin    TX  Austin     Travis        67  221300.0
# 98      92654    78745  Austin    TX  Austin     Travis        99  135000.0
# 422     92667    78758  Austin    TX  Austin     Travis       423  129000.0
# 432     92651    78741  Austin    TX  Austin     Travis       433   93800.0
# 502     92662    78753  Austin    TX  Austin     Travis       503  111300.0
#
#       1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 66   221100.0  221000.0  ...   530100   532400   534200   536200   538200
# 98   134200.0  133800.0  ...   286300   286900   287500   288700   289800
# 422  128300.0  127500.0  ...   250000   248400   247500   247400   247900
# 432   93600.0   93500.0  ...   228000   226700   227600   230200   234100
# 502  110600.0  109900.0  ...   222600   223200   223600   223100   223100
#
#      2017-12  2018-01  2018-02  2018-03  2018-04
# 66    539800   540200   542300   547100   550900
# 98    290500   291300   292600   294000   294700
# 422   250500   255100   260100   266000   270400
# 432   238300   241000   243600   247400   250400
# 502   225000   227100   228700   231500   233400
#
# [5 rows x 272 columns]

# %%
#Check the unique value in the dataset
tx_aus.iloc[:,0:7].nunique()
# Out:
# RegionID      38
# Zipcode       38
# City           1
# State          1
# Metro          1
# CountyName     1
# SizeRank      38
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Reshape from Wide to Long Format

# %%
def melt_data(df):
    ''' 
        Takes a dataframe with datetime data that is in wide format and melts it into long format;      
        Transforms data into datetime object with time as index, defaulted as monthly.                     

        df          Dataframe to transform     
    '''
    
    melted = pd.melt(df, id_vars=['RegionID', 'Zipcode', 'City', 'State', 'Metro', 'CountyName', 'SizeRank'], 
                      var_name='Month', value_name='MeanValue')
    melted['Month'] = pd.to_datetime(melted['Month'], format='%Y-%m')
    melted = melted.dropna(subset=['MeanValue'])
    return melted
#     return melted.groupby('time').aggregate({'value':'mean'})

# %%
tx_aus = melt_data(tx_aus)
tx_aus.head()
# Out:
#    RegionID  Zipcode    City State   Metro CountyName  SizeRank      Month  \
# 0     92617    78704  Austin    TX  Austin     Travis        67 1996-04-01
# 1     92654    78745  Austin    TX  Austin     Travis        99 1996-04-01
# 2     92667    78758  Austin    TX  Austin     Travis       423 1996-04-01
# 3     92651    78741  Austin    TX  Austin     Travis       433 1996-04-01
# 4     92662    78753  Austin    TX  Austin     Travis       503 1996-04-01
#
#    MeanValue
# 0   221300.0
# 1   135000.0
# 2   129000.0
# 3    93800.0
# 4   111300.0

# %% [markdown]
# ### Make the datetime as index

# %%
def make_datetime_index(df,col_index = 'Month', drop=False, verbose=True):
    '''           
         Transforms data into datetime object with time as index, defaulted as monthly     
         
         df          Dataframe to transform     
    '''

    df[col_index] = pd.to_datetime(df[col_index], errors='coerce')
    df = df.set_index('Month', drop=False)
    if verbose:
        display(df.index)
    return df

# %%
tx_aus= make_datetime_index(tx_aus)
# Out:
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01',
#                ...
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Month', length=10070, freq=None)

# %%
'''
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects 
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')
'''
# Out:
# '\ndef get_datetimes(df):\n    """\n    Takes a dataframe:\n    returns only those column names that can be converted into datetime objects \n    as datetime objects.\n    NOTE number of returned columns may not match total number of columns in passed dataframe\n    """\n    \n    return pd.to_datetime(df.columns.values[7:], format=\'%Y-%m\')\n'

# %%
# Use the default frequency "Month"  and group by zipcode
tx_aus_zip = tx_aus.groupby('Zipcode').resample('MS').asfreq()

# %%
tx_aus_zip.head(10)
# Out:
#                     RegionID  Zipcode    City State   Metro CountyName  \
# Zipcode Month
# 78617   1996-04-01     92555    78617  Austin    TX  Austin     Travis
#         1996-05-01     92555    78617  Austin    TX  Austin     Travis
#         1996-06-01     92555    78617  Austin    TX  Austin     Travis
#         1996-07-01     92555    78617  Austin    TX  Austin     Travis
#         1996-08-01     92555    78617  Austin    TX  Austin     Travis
#         1996-09-01     92555    78617  Austin    TX  Austin     Travis
#         1996-10-01     92555    78617  Austin    TX  Austin     Travis
#         1996-11-01     92555    78617  Austin    TX  Austin     Travis
#         1996-12-01     92555    78617  Austin    TX  Austin     Travis
#         1997-01-01     92555    78617  Austin    TX  Austin     Travis
#
#                     SizeRank      Month  MeanValue
# Zipcode Month
# 78617   1996-04-01      6240 1996-04-01   121900.0
#         1996-05-01      6240 1996-05-01   120500.0
#         1996-06-01      6240 1996-06-01   119000.0
#         1996-07-01      6240 1996-07-01   117400.0
#         1996-08-01      6240 1996-08-01   116000.0
#         1996-09-01      6240 1996-09-01   114600.0
#         1996-10-01      6240 1996-10-01   113300.0
#         1996-11-01      6240 1996-11-01   112100.0
#         1996-12-01      6240 1996-12-01   110900.0
#         1997-01-01      6240 1997-01-01   109900.0

# %%
tx_aus_zip.isna().sum()
# Out:
# RegionID      0
# Zipcode       0
# City          0
# State         0
# Metro         0
# CountyName    0
# SizeRank      0
# Month         0
# MeanValue     0
# dtype: int64

# %%
tx_aus_zip['Zipcode'].unique()
# Out:
# array([78617, 78702, 78703, 78704, 78705, 78717, 78721, 78722, 78723,
#        78724, 78725, 78726, 78727, 78728, 78730, 78731, 78732, 78733,
#        78735, 78736, 78737, 78739, 78741, 78744, 78745, 78746, 78747,
#        78748, 78749, 78750, 78751, 78752, 78753, 78754, 78756, 78757,
#        78758, 78759])

# %%
# Calculate the ROI% from the month housing bubble bursted to the end of the dataset
# Housing bubble bursted in December 2008

df_aus_recession = df.loc[df['City'] == 'Austin'].copy()
#df_aus_recession = df_aus_recession.loc[df_aus_recession['City']=='Austin'].copy()
df_aus_recession['ROI'] = ((df_aus_recession['2018-04']- df_aus_recession['2008-12'])
                                  *100)/df_aus_recession['2008-12']
df_aus_recession= df_aus_recession.sort_values(by=['ROI'], ascending=False)
df_aus_recession.head(10)
# Out:
#       RegionID  Zipcode    City State   Metro CountyName  SizeRank   1996-04  \
# 8350     92632    78721  Austin    TX  Austin     Travis      8351   69200.0
# 422      92667    78758  Austin    TX  Austin     Travis       423  129000.0
# 3926     92615    78702  Austin    TX  Austin     Travis      3927   55600.0
# 2462     92634    78723  Austin    TX  Austin     Travis      2463   97600.0
# 432      92651    78741  Austin    TX  Austin     Travis       433   93800.0
# 502      92662    78753  Austin    TX  Austin     Travis       503  111300.0
# 98       92654    78745  Austin    TX  Austin     Travis        99  135000.0
# 1671     92653    78744  Austin    TX  Austin     Travis      1672   85400.0
# 5307     92661    78752  Austin    TX  Austin     Travis      5308   87200.0
# 2644     92638    78727  Austin    TX  Austin     Travis      2645  150300.0
#
#        1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  2017-12  \
# 8350   68800.0   68400.0  ...   281200   281500   284000   288500   293000
# 422   128300.0  127500.0  ...   248400   247500   247400   247900   250500
# 3926   56700.0   57900.0  ...   393000   394600   397100   400600   405200
# 2462   99000.0  100300.0  ...   339000   340500   343100   347800   352500
# 432    93600.0   93500.0  ...   226700   227600   230200   234100   238300
# 502   110600.0  109900.0  ...   223200   223600   223100   223100   225000
# 98    134200.0  133800.0  ...   286900   287500   288700   289800   290500
# 1671   85400.0   85300.0  ...   182900   186000   188400   189700   190900
# 5307   87000.0   86800.0  ...   311900   307000   303100   299800   299300
# 2644  150200.0  150300.0  ...   303800   304200   305300   306900   309300
#
#       2018-01  2018-02  2018-03  2018-04         ROI
# 8350   296300   297800   297200   296100  111.651179
# 422    255100   260100   266000   270400   88.563459
# 3926   410100   413800   417300   419800   82.680592
# 2462   355800   358700   361900   364200   77.745242
# 432    241000   243600   247400   250400   73.167358
# 502    227100   228700   231500   233400   72.633136
# 98     291300   292600   294000   294700   71.038886
# 1671   192100   193200   194500   195500   70.593368
# 5307   300400   301400   302300   303100   66.173246
# 2644   311800   313400   315200   316500   64.929651
#
# [10 rows x 273 columns]

# %%
df_aus_roi=df_aus_recession.head()

# %%
ax=sns.barplot(data=df_aus_roi,x='Zipcode',y='ROI',palette='summer')
ax.set_xlabel('Zipcode')
ax.set_ylabel('ROI')
ax.set_title('Top 5 ROI in Austin Metro Area')
ax.set_xticklabels(ax.get_xticklabels(),rotation=0,ha="right");

# %%
#Select the top 5 zipcodes with highest ROI
zip_select=list(df_aus_recession.Zipcode.values)[0:5]

zip_select
# Out:
# [78721, 78758, 78702, 78723, 78741]

# %% [markdown]
# ## Ploting the Top 5 ROI Zipcodes

# %%
plt.style.use('seaborn-poster')
#ts = tx_aus_zip['MeanValue'].loc[78721]
def plot_ts(df,zip_select, col='MeanValue'):
    
    fig, ax = plt.subplots()
    
    for zc in zip_select:
            ts = df[col].loc[zc]
            ts.plot(label=str(zc), ax=ax)
            
    #max_ = ts.loc['2008':'2018'].idxmax()
    crisis = '12-2008'
    #min_ = ts.loc['2008':'2018'].idxmin()
    ##min_ = ts.loc[crisis:].idxmin()
    #ax.axvline(max_,label=f'Max Price between 2008 to 2018 {max_}',color='green', ls=':')
    ax.axvline(crisis,label=f'Housing Index Drops on {crisis}',color='red', ls=':')
    #ax.axvline(min_,label=f'Min Price between 2008 to 2018 {min_}',color='black')
    ax.set_xlabel('Time')
    ax.set_ylabel('Price')
    ax.legend()
    return fig,ax

# %%
# Plot the top 5 zipcodes with highest ROI
fig,ax = plot_ts(tx_aus_zip, zip_select)

# %% [markdown]
# ## Time Series Modeling for Each Zipcode

# %%
def create_top5(zip_select,df):
    df_5 = pd.DataFrame()
    for zip_code in zip_select:
        
        data = df.loc[(df['Zipcode']==zip_code)]
        df_5=pd.concat([data,df_5],axis=0)
        
    return df_5

# %%
df_aus_5 = create_top5(zip_select, df)

# %%
'''
# Create a data frame for top 5 ROI zipcodes
df_aus_5 = df.loc[(df['Zipcode'] == 78721) |
                        (df['Zipcode'] == 78758) |
                           (df['Zipcode'] == 78702) |
                           (df['Zipcode'] == 78723) |
                           (df['Zipcode'] == 78957)].copy()

'''
# Out:
# "\n# Create a data frame for top 5 ROI zipcodes\ndf_aus_5 = df.loc[(df['Zipcode'] == 78721) |\n                        (df['Zipcode'] == 78758) |\n                           (df['Zipcode'] == 78702) |\n                           (df['Zipcode'] == 78723) |\n                           (df['Zipcode'] == 78957)].copy()\n\n"

# %%
df_aus_5.head()
# Out:
#       RegionID  Zipcode    City State   Metro CountyName  SizeRank   1996-04  \
# 432      92651    78741  Austin    TX  Austin     Travis       433   93800.0
# 2462     92634    78723  Austin    TX  Austin     Travis      2463   97600.0
# 3926     92615    78702  Austin    TX  Austin     Travis      3927   55600.0
# 422      92667    78758  Austin    TX  Austin     Travis       423  129000.0
# 8350     92632    78721  Austin    TX  Austin     Travis      8351   69200.0
#
#        1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 432    93600.0   93500.0  ...   228000   226700   227600   230200   234100
# 2462   99000.0  100300.0  ...   336300   339000   340500   343100   347800
# 3926   56700.0   57900.0  ...   391700   393000   394600   397100   400600
# 422   128300.0  127500.0  ...   250000   248400   247500   247400   247900
# 8350   68800.0   68400.0  ...   279600   281200   281500   284000   288500
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 432    238300   241000   243600   247400   250400
# 2462   352500   355800   358700   361900   364200
# 3926   405200   410100   413800   417300   419800
# 422    250500   255100   260100   266000   270400
# 8350   293000   296300   297800   297200   296100
#
# [5 rows x 272 columns]

# %%
df_aus_5 = melt_data(df_aus_5)

# %%
df_aus_5 = make_datetime_index(df_aus_5)
# Out:
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-05-01', '1996-05-01', '1996-05-01',
#                '1996-05-01', '1996-05-01',
#                ...
#                '2018-03-01', '2018-03-01', '2018-03-01', '2018-03-01',
#                '2018-03-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Month', length=1325, freq=None)

# %%
df_aus_5.head()
# Out:
#             RegionID  Zipcode    City State   Metro CountyName  SizeRank  \
# Month
# 1996-04-01     92651    78741  Austin    TX  Austin     Travis       433
# 1996-04-01     92634    78723  Austin    TX  Austin     Travis      2463
# 1996-04-01     92615    78702  Austin    TX  Austin     Travis      3927
# 1996-04-01     92667    78758  Austin    TX  Austin     Travis       423
# 1996-04-01     92632    78721  Austin    TX  Austin     Travis      8351
#
#                 Month  MeanValue
# Month
# 1996-04-01 1996-04-01    93800.0
# 1996-04-01 1996-04-01    97600.0
# 1996-04-01 1996-04-01    55600.0
# 1996-04-01 1996-04-01   129000.0
# 1996-04-01 1996-04-01    69200.0

# %%
df_aus_5zip = df_aus_5.groupby('Zipcode').resample('MS').asfreq()

# %%
df_aus_5zip.isna().sum()
# Out:
# RegionID      0
# Zipcode       0
# City          0
# State         0
# Metro         0
# CountyName    0
# SizeRank      0
# Month         0
# MeanValue     0
# dtype: int64

# %%
df_aus_5zip.head(10)
# Out:
#                     RegionID  Zipcode    City State   Metro CountyName  \
# Zipcode Month
# 78702   1996-04-01     92615    78702  Austin    TX  Austin     Travis
#         1996-05-01     92615    78702  Austin    TX  Austin     Travis
#         1996-06-01     92615    78702  Austin    TX  Austin     Travis
#         1996-07-01     92615    78702  Austin    TX  Austin     Travis
#         1996-08-01     92615    78702  Austin    TX  Austin     Travis
#         1996-09-01     92615    78702  Austin    TX  Austin     Travis
#         1996-10-01     92615    78702  Austin    TX  Austin     Travis
#         1996-11-01     92615    78702  Austin    TX  Austin     Travis
#         1996-12-01     92615    78702  Austin    TX  Austin     Travis
#         1997-01-01     92615    78702  Austin    TX  Austin     Travis
#
#                     SizeRank      Month  MeanValue
# Zipcode Month
# 78702   1996-04-01      3927 1996-04-01    55600.0
#         1996-05-01      3927 1996-05-01    56700.0
#         1996-06-01      3927 1996-06-01    57900.0
#         1996-07-01      3927 1996-07-01    59300.0
#         1996-08-01      3927 1996-08-01    60800.0
#         1996-09-01      3927 1996-09-01    62500.0
#         1996-10-01      3927 1996-10-01    64300.0
#         1996-11-01      3927 1996-11-01    66200.0
#         1996-12-01      3927 1996-12-01    68200.0
#         1997-01-01      3927 1997-01-01    70300.0

# %%
#df_aus_zipgroup.index
#U.S. housing bubble bursted in Dec 2008
#Use data from Jan 2009 to April 2018
df_aus_5zip_index = df_aus_5zip.loc[pd.IndexSlice[:,'2009-01-01':],:].copy()
df_aus_5zip_index.tail()
# Out:
#                     RegionID  Zipcode    City State   Metro CountyName  \
# Zipcode Month
# 78758   2017-12-01     92667    78758  Austin    TX  Austin     Travis
#         2018-01-01     92667    78758  Austin    TX  Austin     Travis
#         2018-02-01     92667    78758  Austin    TX  Austin     Travis
#         2018-03-01     92667    78758  Austin    TX  Austin     Travis
#         2018-04-01     92667    78758  Austin    TX  Austin     Travis
#
#                     SizeRank      Month  MeanValue
# Zipcode Month
# 78758   2017-12-01       423 2017-12-01   250500.0
#         2018-01-01       423 2018-01-01   255100.0
#         2018-02-01       423 2018-02-01   260100.0
#         2018-03-01       423 2018-03-01   266000.0
#         2018-04-01       423 2018-04-01   270400.0

# %%
df_aus_5zip_index.reset_index(inplace=True,level=0,drop=True)
df_aus_5zip_index.head()
# Out:
#             RegionID  Zipcode    City State   Metro CountyName  SizeRank  \
# Month
# 2009-01-01     92615    78702  Austin    TX  Austin     Travis      3927
# 2009-02-01     92615    78702  Austin    TX  Austin     Travis      3927
# 2009-03-01     92615    78702  Austin    TX  Austin     Travis      3927
# 2009-04-01     92615    78702  Austin    TX  Austin     Travis      3927
# 2009-05-01     92615    78702  Austin    TX  Austin     Travis      3927
#
#                 Month  MeanValue
# Month
# 2009-01-01 2009-01-01   230200.0
# 2009-02-01 2009-02-01   230500.0
# 2009-03-01 2009-03-01   230900.0
# 2009-04-01 2009-04-01   230800.0
# 2009-05-01 2009-05-01   230300.0

# %%
ts_78721 = df_aus_5zip_index[df_aus_5zip_index['Zipcode']==78721]
ts_78721 = ts_78721['MeanValue']
ts_78721 = ts_78721.rename('78721')
ts_78721.head()
# Out:
# Month
# 2009-01-01    139700.0
# 2009-02-01    139500.0
# 2009-03-01    139200.0
# 2009-04-01    138700.0
# 2009-05-01    138400.0
# Name: 78721, dtype: float64

# %%
ts_78723 = df_aus_5zip_index[df_aus_5zip_index['Zipcode']==78723]
ts_78723 = ts_78723['MeanValue']
ts_78723 = ts_78723.rename('78723')
ts_78723.head()
# Out:
# Month
# 2009-01-01    205000.0
# 2009-02-01    205300.0
# 2009-03-01    205500.0
# 2009-04-01    206000.0
# 2009-05-01    206600.0
# Name: 78723, dtype: float64

# %%
ts_78741 = df_aus_5zip_index[df_aus_5zip_index['Zipcode']==78741]
ts_78741 = ts_78741['MeanValue']
ts_78741 = ts_78741.rename('78741')
ts_78741.head()
# Out:
# Month
# 2009-01-01    144100.0
# 2009-02-01    143600.0
# 2009-03-01    143100.0
# 2009-04-01    142600.0
# 2009-05-01    142300.0
# Name: 78741, dtype: float64

# %%
ts_78758 = df_aus_5zip_index[df_aus_5zip_index['Zipcode']==78758]
ts_78758 = ts_78758['MeanValue']
ts_78758 = ts_78758.rename('78758')

# %%
ts_78702 = df_aus_5zip_index[df_aus_5zip_index['Zipcode']==78702]
ts_78702 = ts_78702['MeanValue']
ts_78702 = ts_78702.rename('78702')

# %%
ts_set = [ts_78721,ts_78723,ts_78758,ts_78702,ts_78741]

# %% [markdown]
# ## Check Stationarity

# %%
def check_stationarity(ts):
    roll_mean = ts.rolling(window=8, center=False).mean()
    roll_std = ts.rolling(window=8, center=False).std()

    fig = plt.figure(figsize=(12,7))
    plt.plot(ts, color='green', label='Original')
    plt.plot(roll_mean, color='blue', label='Rolling Mean')
    plt.plot(roll_std, color='red', label = 'Rolling STD')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    dftest = adfuller(ts)

    # Extract and display test results in a user friendly manner
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
        
    print ('Results of Dickey-Fuller test: \n')

    print(dfoutput)
    
    
    return None

# %%
for ts, name in zip(ts_set, zip_select):
    print(f'\n\n Zipcode: {name}\n')
    check_stationarity(ts)
# Out:
#  Zipcode: 78721
# Results of Dickey-Fuller test:
#
# Test Statistic                   0.586320
# p-value                          0.987274
# #Lags Used                       8.000000
# Number of Observations Used    103.000000
# Critical Value (1%)             -3.495493
# Critical Value (5%)             -2.890037
# Critical Value (10%)            -2.581971
# dtype: float64
#
#
#  Zipcode: 78758
# Results of Dickey-Fuller test:
#
# Test Statistic                   0.869047
# p-value                          0.992673
# #Lags Used                      11.000000
# Number of Observations Used    100.000000
# Critical Value (1%)             -3.497501
# Critical Value (5%)             -2.890906
# Critical Value (10%)            -2.582435
# dtype: float64
#
#
#  Zipcode: 78702
# Results of Dickey-Fuller test:
#
# Test Statistic                   2.183920
# p-value                          0.998869
# #Lags Used                      10.000000
# Number of Observations Used    101.000000
# Critical Value (1%)             -3.496818
# Critical Value (5%)             -2.890611
# Critical Value (10%)            -2.582277
# dtype: float64
#
#
#  Zipcode: 78723
# Results of Dickey-Fuller test:
#
# Test Statistic                   0.346203
# p-value                          0.979368
# #Lags Used                       8.000000
# Number of Observations Used    103.000000
# Critical Value (1%)             -3.495493
# Critical Value (5%)             -2.890037
# Critical Value (10%)            -2.581971
# dtype: float64
#
#
#  Zipcode: 78741
# Results of Dickey-Fuller test:
#
# Test Statistic                   1.904523
# p-value                          0.998535
# #Lags Used                       4.000000
# Number of Observations Used    107.000000
# Critical Value (1%)             -3.492996
# Critical Value (5%)             -2.888955
# Critical Value (10%)            -2.581393
# dtype: float64

# %% [markdown]
# We can know the data is not stationary based on two observation. One thing is from above plots, rolling mean is increasing. The other is that the P-value in each test is larger than 0.05. It means fail to reject the null hypothesis.

# %% [markdown]
# ## Decomposition

# %% [markdown]
# We also want to know if the data is seasonality. So we use seasonal decomposition.

# %%
# Decompose time series
for ts in ts_set:
    result = seasonal_decompose(ts, model='additive')
    result.plot()

# %% [markdown]
# From above decomposition plots, seasonality is observed in the dataset.

# %% [markdown]
# ## Check Auto Correlation and Partial Auto Correlation

# %%
def acf_pacf(df,alags=30,plags=30):
    ''' 
        Performs acf/pacf results plot      
                             
        df          Dataframe to Analyse     
    '''

    #Create figure
    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(14,12))
    #Make ACF plot
    plot_acf(df,lags=alags, zero=False,ax=ax1)
    #Make PACF plot
    plot_pacf(df,lags=plags, ax=ax2)
    plt.show()

# %% [markdown]
# ### Check ACF and PACF for selected zipcodes

# %%
# Check ACF and PACF plots  for each zipcode
for ts, name in zip(ts_set, zip_select):
    print(f'\n \n Zipcode {name} \n')
    acf_pacf(ts)
# Out:
#
#  Zipcode 78721
#
#  Zipcode 78758
#
#  Zipcode 78702
#
#  Zipcode 78723
#
#  Zipcode 78741

# %% [markdown]
# ## ARIMA Time Series Model

# %% [markdown]
# ### Parameter Selection for the ARIMA Time Series Model

# %%
def AIC_PDQS(df):   
    ''' 
         Runs grid search to return lowest AIC result for permutataions of pdq/s values in range 0,2  
                          
         df          Dataframe to anlyse for best pdq/s permutation    
    '''
    
    # Define the p, d and q parameters to take any value between 0 and 2
    p = d = q = range(0, 2)
    
#     Auto-Regressive (p) -> Number of autoregressive terms.
#     Integrated (d) -> Number of nonseasonal differences needed for stationarity.
#     Moving Average (q) -> Number of lagged forecast errors in the prediction equation.

    # Generate all different combinations of p, q and q triplets
    pdq = list(itertools.product(p, d, q))

    # Generate all different combinations of seasonal p, q and q triplets
    pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]


    # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                mod = sm.tsa.statespace.SARIMAX(df,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

                output = mod.fit()
                ans.append([comb, combs, output.aic])
                print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
            except:
                continue
            
    # Find the parameters with minimal AIC value
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
    print(ans_df.loc[ans_df['aic'].idxmin()])
    return ans_df

# %%
AIC_PDQS(ts_78702)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.38870D+01    |proj g|=  1.11910D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.119D-08   1.389D+01
#   F =   13.887027823194225
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =3112.6942323955063
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.51846D+03    |proj g|=  2.34140D+01
#
# At iterate    5    f=  1.21549D+01    |proj g|=  5.87575D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     14      1     0     0   3.685D-06   1.215D+01
#   F =   12.154937906453918
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =2726.7060910456776
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03084D+01    |proj g|=  4.41087D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   4.411D-06   1.031D+01
#   F =   10.308358131071902
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =2311.072221360106
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.25917D+03    |proj g|=  2.59978D+01
#
# At iterate    5    f=  4.65148D+01    |proj g|=  4.41650D-01
#
# At iterate   10    f=  1.81728D+01    |proj g|=  2.14923D-02
#
# At iterate   15    f=  1.49598D+01    |proj g|=  8.56524D-04
#
# At iterate   20    f=  1.48139D+01    |proj g|=  4.58089D-05
#   ys=-3.546E+01  -gs= 7.107E-01 BFGS update SKIPPED
#
# At iterate   25    f=  9.14871D+00    |proj g|=  2.85820D-02
#   ys=-1.625E+01  -gs= 7.534E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     29     66      1     2     0   1.574D-07   9.100D+00
#   F =   9.0995374513752676
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =2042.29638910806
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.97002D+00    |proj g|=  1.18060D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     12      1     0     0   1.180D-03   9.970D+00
#   F =   9.9700235063512217
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =2237.2852654226735
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.71040D+03    |proj g|=  7.25824D+02
#
# At iterate    5    f=  1.57682D+03    |proj g|=  6.71004D+02
#
# At iterate   10    f=  2.80754D+01    |proj g|=  5.76599D+01
#
# At iterate   15    f=  1.01838D+01    |proj g|=  4.65781D+00
#
# At iterate   20    f=  9.78676D+00    |proj g|=  2.86011D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     30      1     0     0   3.143D-04   9.787D+00
#   F =   9.7867552430613198
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =2198.2331744457356
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.77832D+00    |proj g|=  1.07889D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     13      1     0     0   1.073D-05   8.778D+00
#   F =   8.7783191603250064
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =1970.3434919128013
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.21866D+03    |proj g|=  1.52213D+02
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iter
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.62940D+00    |proj g|=  3.25692D+00
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  6.47304D+00    |proj g|=  8.53995D-02
#
# At iterate   10    f=  6.47075D+00    |proj g|=  6.02443D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     10     12      1     0     0   6.024D-06   6.471D+00
#   F =   6.4707540139155881
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =1457.4488991170917
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.53977D+01    |proj g|=  2.08538D+01
#
# At iterate    5    f=  7.33898D+00    |proj g|=  5.25287D-01
#
# At iterate   10    f=  7.14708D+00    |proj g|=  1.70222D-01
#
# At iterate   15    f=  7.14261D+00    |proj g|=  5.91793D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     20      1     0     0   5.918D-07   7.143D+00
#   F =   7.1426119971939359
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =1607.9450873714416
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.17068D+00    |proj g|=  3.82225D+00
#
# At iterate    5    f=  7.07279D+00    |proj g|=  1.64576D-01
#
# At iterate   10    f=  7.07022D+00    |proj g|=  5.72618D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     13     16      1     0     0   2.007D-05   7.070D+00
#   F =   7.0702078779259789
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =1593.7265646554192
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.11227D+01    |proj g|=  5.50051D+01
#
# At iterate    5    f=  6.66553D+00    |proj g|=  2.74057D-01
#  This problem is unconstrained.
# At iterate   10    f=  6.56908D+00    |proj g|=  1.94745D-01
#
# At iterate   15    f=  6.55634D+00    |proj g|=  1.31264D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     16     21      1     0     0   1.517D-04   6.556D+00
#   F =   6.5563409164076498
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =1476.6203652753136
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.80890D+01    |proj g|=  6.04498D+01
#
# At iterate    5    f=  6.76296D+00    |proj g|=  6.37963D-01
#
# At iterate   10    f=  6.51475D+00    |proj g|=  4.14947D-01
#
# At iterate   15    f=  6.42433D+00    |proj g|=  8.66072D-02
#  This problem is unconstrained.
# At iterate   20    f=  6.42011D+00    |proj g|=  9.68661D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     23     41      1     0     0   2.075D-04   6.420D+00
#   F =   6.4200881372021312
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =1448.0997427332775
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic       1448.099743
# Name: 63, dtype: object
#           pdq           pdqs          aic
# 0   (0, 0, 0)  (0, 0, 0, 12)  3112.694232
# 1   (0, 0, 0)  (0, 0, 1, 12)  2726.706091
# 2   (0, 0, 0)  (0, 1, 0, 12)  2311.072221
# 3   (0, 0, 0)  (0, 1, 1, 12)  2042.296389
# 4   (0, 0, 0)  (1, 0, 0, 12)  2237.285265
# ..        ...            ...          ...
# 59  (1, 1, 1)  (0, 1, 1, 12)  1457.448899
# 60  (1, 1, 1)  (1, 0, 0, 12)  1607.945087
# 61  (1, 1, 1)  (1, 0, 1, 12)  1593.726565
# 62  (1, 1, 1)  (1, 1, 0, 12)  1476.620365
# 63  (1, 1, 1)  (1, 1, 1, 12)  1448.099743
#
# [64 rows x 3 columns]

# %% [markdown]
# ### Train Test Split Function

# %%
# Train, test split
def train_test(df):
   
    #Use data before 2017-05 as training data set 
    train = df[:'2017-05']
    #Use 12 month prior to 2018-04 as test data set test, which starts from 2017-05
    test = df['2017-05':]
    return train, test

# %% [markdown]
# ### Fitting an ARIMA Time Series Model

# %%
def model_fit(df,pdq=(1,0,1),pdqs=(0,0,0,1)):
    ''' 
        Performs SARAMA model given defined pdq/s values and returns results     
        
        df          Dataframe to Analyse   
        
        Returns train/test df on the same df modelled   
    '''

    train, test = train_test(df)
    model = SARIMAX(train,order=pdq,seasonal_order=pdqs, 
                                        )
    results = model.fit()
    results.summary
    residuals = results.resid
    print(results.summary())
    results.plot_diagnostics(figsize=(14,14))
    plt.show();
    return train, test, results


#print(output.summary().tables[1])

# %%
#Fit the SARIMA model and get results.
pdq = (1, 1, 1)
pdqs = (1, 1, 1, 12)

train, test, results = model_fit(ts_78702,pdq=pdq,pdqs=pdqs)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.44442D+01    |proj g|=  3.25356D+01
#
# At iterate    5    f=  9.21474D+00    |proj g|=  1.25322D+00
#
# At iterate   10    f=  9.17903D+00    |proj g|=  2.92406D-03
#
# At iterate   15    f=  9.17890D+00    |proj g|=  3.45519D-02
#  This problem is unconstrained.
# At iterate   20    f=  9.14020D+00    |proj g|=  3.18916D-01
#
# At iterate   25    f=  8.12308D+00    |proj g|=  2.10793D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     28     50      1     0     0   4.572D-05   8.121D+00
#   F =   8.1214264699481173
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              78702   No. Observations:                  101
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -820.264
# Date:                            Sun, 16 Oct 2022   AIC                           1650.528
# Time:                                    16:39:34   BIC                           1662.915
# Sample:                                01-01-2009   HQIC                          1655.518
#                                      - 05-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      2.029      0.493      0.622      -2.976       4.976
# ma.L1         -1.0000      2.067     -0.484      0.628      -5.051       3.051
# ar.S.L12      -0.9999      0.898     -1.113      0.266      -2.761       0.761
# ma.S.L12       0.9999      0.901      1.110      0.267      -0.765       2.765
# sigma2       6.99e+06   5.32e-06   1.31e+12      0.000    6.99e+06    6.99e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  54.26   Jarque-Bera (JB):                 0.17
# Prob(Q):                              0.00   Prob(JB):                         0.92
# Heteroskedasticity (H):               0.98   Skew:                             0.00
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.32e+27. Standard errors may be unstable.

# %%
def test_model(df,pdq=(1,0,1),pdqs=(0,0,0,1), display=True):
    ''' 
            Predicts for 12 months on test model with SARIMA model  
                      
            df          Dataframe to perform predictions    
    '''

    X = df.values
    train, test = X[:-12],X[-12:]
    history = [x for x in train]
    predictions = []
    for t in range(len(test)):
        model = SARIMAX(history, order=pdq,seasonal_order=pdqs, enforce_stationarity=False, 
                                        enforce_invertibility=False)
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        history.append(test[t])
    mse= mean_squared_error(test,predictions)
    rmse = math.sqrt(mse)
    print(f'SARIMA model RMSE on train data: %.5f' % rmse)
    #rmse = sqrt(MSE(test, predictions))
    #print('SARIMA model RMSE on test data: %.5f' % rmse)
    #print('SARIMA model RMSE on test data')
    if display:
        plt.figure(figsize=(13,6))
        plt.title('Actual Test Data vs. Predictions')
        plt.plot(history[-12:],label='Actual', color='b')
        plt.plot(predictions,label='Predictions',color='g')
        plt.legend(loc='best')
        plt.show()

# %%
def train_model(train, results, display = True):
    ''' 
        Returns train versus test predictions pefromed on on SARIMA model    
        Transforms data into datetime object with time as index.                     

        train          Train Dataframe for period defined
        results        Results from SARIMA model
    '''

    train_pred = results.predict(-12)
    mse= mean_squared_error(train[-12:],train_pred)
    rmse = math.sqrt(mse)
    print(f'SARIMA model RMSE on train data: %.5f' % rmse)
    
    if display:
        plt.figure(figsize=(13,6))
        train[-60:].plot(label='Actual Train',color='b')
        train_pred.plot(label='Predicted',color='g')
        plt.legend(loc='best')
        plt.title('Actual Train Data vs. Predicted Returns')
        plt.show()

# %%
train_model(train,results)
# Out:
# SARIMA model RMSE on train data: 3554.56977

# %%
test_model(ts_78702,pdq=pdq,pdqs=pdqs,display=True)
# Out:
# SARIMA model RMSE on train data: 782.62592

# %% [markdown]
# ## Validating the Model

# %%
'''
#Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(co2,
                                        order=(1,1,1),
                                        seasonal_order=(1,1,1,12),
                                        enforce_stationarity=False,
                                        enforce_invertibility=False)

# Fit the model and print results

output=ARIMA_MODEL.fit()



print(output.summary().tables[1])
'''
# Out:
#   File "/var/folders/rl/9gt5xn152vzbj84ndjq5sbgm0000gn/T/ipykernel_1884/2109676876.py", line 15
#     print(output.summary().tables[1])
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
'''
pred_dynamic = output.get_prediction(start=pd.to_datetime('1998-01-01'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

'''

# %%
'''
# Extract the predicted and true values of our time series
co2_forecasted = pred_dynamic.predicted_mean
Co2_truth = co2['1998-01-01':]

# Compute the mean square error
mse = ((co2_forecasted-co2_truth)**2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))

'''
# Out:
# "\n# Extract the predicted and true values of our time series\nco2_forecasted = pred_dynamic.predicted_mean\nCo2_truth = co2['1998-01-01':]\n\n# Compute the mean square error\nmse = ((co2_forecasted-co2_truth)**2).mean()\nprint('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))\n\n"

# %%
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(ts_78721,
                                        order=(1,1,1),
                                        seasonal_order=(1,1,1,12),
                                        enforce_stationarity=False,
                                        enforce_invertibility=False)
output= ARIMA_MODEL.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.57025D+00    |proj g|=  6.49412D+00
#
# At iterate    5    f=  6.40126D+00    |proj g|=  2.44188D-01
#
# At iterate   10    f=  6.33497D+00    |proj g|=  1.56754D-01
#
# At iterate   15    f=  6.32700D+00    |proj g|=  5.49381D-03
#
# At iterate   20    f=  6.32698D+00    |proj g|=  1.17917D-03
#  This problem is unconstrained.
# At iterate   25    f=  6.32688D+00    |proj g|=  8.53440D-02
#
# At iterate   30    f=  6.32029D+00    |proj g|=  2.42805D-01
#
# At iterate   35    f=  6.31483D+00    |proj g|=  4.10618D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     38     45      1     0     0   9.481D-06   6.315D+00
#   F =   6.3148169261728855
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
pred_dynamic = output.get_prediction(start=pd.to_datetime('2017-04-01'), dynamic=True, full_results=True)

# %%
def forecast_model(df,pdq=(1,0,1),pdqs=(0,0,0,1), display=True,zc='enter zipcode'):
    
    ''' 
        Performs predictions on SARIMA model up to 10 years in the future   
                           
         df          Dataframe to model    
    '''

    #model = SARIMAX(df, order=pdq,seasonal_order=pdqs, enforce_stationarity=False, 
                                        #enforce_invertibility=False)
    model = SARIMAX(df, order=pdq,seasonal_order=pdqs)

    output = model.fit()
    pred_dynamic = output.get_prediction(start='2017-05',end='2022-06', dynamic=True,full_results=True)
    pred_dynamic_ci = pred_dynamic.conf_int()
    
    
    if display:
        fig, ax = plt.subplots(figsize=(13,6))
        pred_dynamic.predicted_mean.plot(label='Forecast')
        ax.fill_between(pred_dynamic_ci.index,pred_dynamic_ci.iloc[:, 0],pred_dynamic_ci.iloc[:, 1],
                        color='k', alpha=.25,label='Conf Interval')
        plt.title('Housing Price Prediction from May 2017 to May 2022')
        plt.xlabel('Time')
        plt.legend(loc='best')
        plt.show()

        year_0 = pred_dynamic.predicted_mean['2017-05-01']
        year_1= pred_dynamic.predicted_mean['2018-05-01']
        year_1_ROI_100K = ((year_1 - year_0)*100)/year_0
        year_3= pred_dynamic.predicted_mean['2020-05-01']
        year_3_ROI_100K = ((year_3 - year_0)*100)/year_0
        year_5= pred_dynamic.predicted_mean['2022-05-01']
        year_5_ROI_100K = ((year_5 - year_0)*100)/year_0
       
        
        print(f'Forecast housing price at enter point date 2017-05: {round(year_0,2)}')
        #print(f'Total expected return in 1 year: {round(year_1*100,2)}%')
        print(f'Forecast housing price in year 1: {round(year_1,2)} with {round(year_1_ROI_100K,2)} % ROI')
        print(f'Forecast housing price in year 3: {round(year_3,2)} with {round(year_3_ROI_100K,2)} % ROI')
        print(f'Forecast housing price in year 5: {round(year_5,2)} with  {round(year_5_ROI_100K,2)} % ROI')
        

        tot_ret = [zc,year_1,year_3,year_5]
    return tot_ret

# %%
print('Zipcode 78702 Property Mean Value Forecast:')
pred_78702 = forecast_model(ts_78702,pdq=pdq,pdqs=pdqs,zc=78702)
# Out:
# Zipcode 78702 Property Mean Value Forecast:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.58734D+01    |proj g|=  3.58720D+01
#
# At iterate    5    f=  9.43539D+00    |proj g|=  1.52701D+00
#
# At iterate   10    f=  9.14177D+00    |proj g|=  1.10285D-02
#
# At iterate   15    f=  9.14156D+00    |proj g|=  1.12393D-01
#
# At iterate   20    f=  9.13200D+00    |proj g|=  7.80557D-01
#  This problem is unconstrained.
# At iterate   25    f=  9.09247D+00    |proj g|=  4.33908D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   30    f=  9.00256D+00    |proj g|=  1.37666D+00
#   ys=-1.117E-04  -gs= 5.048E-05 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     33    121      3     1     0   2.908D+00   9.003D+00
#   F =   9.0025486194286835
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# Forecast property mean value at initial investment date 2017-05: 395699.6
# Forecast property mean value in 1 year: 423098.3 is 6.92 %ROI
# Forecast property mean value in 3 years: 477893.0 is 20.77 %ROI
# Forecast property mean value in 5 years: 532684.23 is 34.62 %ROI

# %%
#Initialise collection of 5yr ROI data for each of the 5 top zipcodes
zip_roi= {'Zipcode': [78702, 78758,78721,78723,78741], '5_YR_PRED_ROI': [0,0,0,0,0]}
df_zip_5YR_ROI = pd.DataFrame(data=zip_roi)

# %%
# Add the 5 yr roi to the results summary df
df_zip_5YR_ROI.loc[df_zip_5YR_ROI['Zipcode'] == 78702, '5YR_PRED_ROI'] = 34.83
df_zip_5YR_ROI
# Out:
#    Zipcode  5_YR_PRED_ROI  5YR_PRED_ROI
# 0    78702              0         34.83
# 1    78758              0           NaN
# 2    78721              0           NaN
# 3    78723              0           NaN
# 4    78741              0           NaN

# %% [markdown]
# ## Zipcode 78758

# %%
AIC_PDQS(ts_78758)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.33918D+01    |proj g|=  1.77636D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.776D-08   1.339D+01
#   F =   13.391819788263229
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =3001.767632570963
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05796D+03    |proj g|=  1.23360D+00
#
# At iterate    5    f=  1.17053D+01    |proj g|=  7.24249D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     23      1     0     0   6.396D-06   1.170D+01
#   F =   11.702867677745562
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =2625.442359815006
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00176D+01    |proj g|=  6.13145D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   6.131D-06   1.002D+01
#   F =   10.017550511103925
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =2245.9313144872795
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.
-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     15     16      1     0     0   1.485D-04   6.098D+00
#   F =   6.0979663159544364
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =1375.9444547737937
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic       1375.944455
# Name: 63, dtype: object
#           pdq           pdqs          aic
# 0   (0, 0, 0)  (0, 0, 0, 12)  3001.767633
# 1   (0, 0, 0)  (0, 0, 1, 12)  2625.442360
# 2   (0, 0, 0)  (0, 1, 0, 12)  2245.931314
# 3   (0, 0, 0)  (0, 1, 1, 12)  1986.330219
# 4   (0, 0, 0)  (1, 0, 0, 12)  2193.616151
# ..        ...            ...          ...
# 59  (1, 1, 1)  (0, 1, 1, 12)  1382.190487
# 60  (1, 1, 1)  (1, 0, 0, 12)  1523.332171
# 61  (1, 1, 1)  (1, 0, 1, 12)  1503.621022
# 62  (1, 1, 1)  (1, 1, 0, 12)  1395.905420
# 63  (1, 1, 1)  (1, 1, 1, 12)  1375.944455
#
# [64 rows x 3 columns]

# %%
pdq = (1, 1, 1)
pdqs = (1, 1, 1, 12)

train,test,results = model_fit(ts_78758,pdq=pdq,pdqs=pdqs)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.63264D+01    |proj g|=  1.01094D+01
#
# At iterate    5    f=  8.88368D+00    |proj g|=  2.59045D-01
#
# At iterate   10    f=  8.86981D+00    |proj g|=  3.43447D-01
#
# At iterate   15    f=  8.67003D+00    |proj g|=  9.60846D-01
#
# At iterate   20    f=  8.63663D+00    |proj g|=  4.70184D-02
#
# At iterate   25    f=  8.63614D+00    |proj g|=  8.33851D-02
#  This problem is unconstrained.
# At iterate   30    f=  8.62154D+00    |proj g|=  3.87996D-01
#
# At iterate   35    f=  8.61476D+00    |proj g|=  4.42997D-03
#
# At iterate   40    f=  8.61355D+00    |proj g|=  1.62317D-01
#
# At iterate   45    f=  8.43252D+00    |proj g|=  1.41915D+00
#
# At iterate   50    f=  7.63248D+00    |proj g|=  3.88939D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     57      1     0     0   3.889D-02   7.632D+00
#   F =   7.6324848786468742
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              78758   No. Observations:                  101
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -770.881
# Date:                            Sun, 16 Oct 2022   AIC                           1551.762
# Time:                                    16:40:35   BIC                           1564.149
# Sample:                                01-01-2009   HQIC                          1556.752
#                                      - 05-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6328      0.584      1.084      0.279      -0.512       1.777
# ma.L1         -0.6131      0.591     -1.037      0.300      -1.772       0.545
# ar.S.L12      -0.9803      0.609     -1.611      0.107      -2.173       0.213
# ma.S.L12       0.9856      0.628      1.569      0.117      -0.246       2.217
# sigma2      2.167e+06   1.01e-06   2.14e+12      0.000    2.17e+06    2.17e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  52.86   Jarque-Bera (JB):                15.70
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.50   Skew:                             0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.37e+27. Standard errors may be unstable.

# %%
train_model(train,results)
# Out:
# SARIMA model RMSE on train data: 2919.19765

# %%
test_model(ts_78758,pdq=pdq,pdqs=pdqs)
# Out:
# SARIMA model RMSE on train data: 1358.95470

# %%
pdq = (1, 1, 1)
pdqs = (1, 1, 1, 12)
pred_78758=forecast_model(ts_78758,pdq=pdq,pdqs=pdqs,zc=78758)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.78633D+01    |proj g|=  1.18473D+01
#
# At iterate    5    f=  9.57297D+00    |proj g|=  2.60268D-01
#
# At iterate   10    f=  9.47534D+00    |proj g|=  2.57474D+00
#
# At iterate   15    f=  9.25442D+00    |proj g|=  2.17349D-02
#
# At iterate   20    f=  9.25428D+00    |proj g|=  5.05251D-02
#  This problem is unconstrained.
# At iterate   25    f=  9.25383D+00    |proj g|=  4.09520D-03
#
# At iterate   30    f=  9.25371D+00    |proj g|=  6.29097D-02
#
# At iterate   35    f=  9.23905D+00    |proj g|=  6.63341D-01
#
# At iterate   40    f=  8.10283D+00    |proj g|=  3.31580D-02
#
# At iterate   45    f=  8.03296D+00    |proj g|=  1.46618D-03
#
# At iterate   50    f=  8.03110D+00    |proj g|=  8.40657D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     56      1     0     0   8.407D-04   8.031D+00
#   F =   8.0311013451923490
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Forecast property mean value at initial investment date 2017-05: 253804.03
# Forecast property mean value in 1 year: 297397.73 is 17.18 %ROI
# Forecast property mean value in 3 years: 383575.1 is 51.13 %ROI
# Forecast property mean value in 5 years: 469250.44 is 84.89 %ROI

# %%
# Add the 5 yr roi to the results summary df
df_zip_5YR_ROI.loc[df_zip_5YR_ROI['Zipcode'] == 78758, '5YR_PRED_ROI'] = 84.89
df_zip_5YR_ROI
# Out:
#    Zipcode  5_YR_PRED_ROI  5YR_PRED_ROI
# 0    78702              0         34.83
# 1    78758              0         84.89
# 2    78721              0           NaN
# 3    78723              0           NaN
# 4    78741              0           NaN

# %% [markdown]
# ### Zipcode 78721

# %% [markdown]
# ### AIC_PDQS

# %%
AIC_PDQS(ts_78721)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.34625D+01    |proj g|=  2.18492D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   2.185D-08   1.346D+01
#   F =   13.462543713814764
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =3017.609791894507
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.72273D+02    |proj g|=  1.67517D+00
#
# At iterate    5    f=  1.18049D+01    |proj g|=  1.66953D-01
#
# At iterate   10    f=  1.17816D+01    |proj g|=  2.94058D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     20      1     0     0   2.941D-06   1.178D+01
#   F =   11.781614864310470
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =2643.081729605545
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01713D+01    |proj g|=  5.14344D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   5.143D-06   1.017D+01
#   F =   10.171298610784964
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =2280.370888815832
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.59444D+02    |proj g|=  1.47029D+01
#
# At iterate    5    f=  3.41273D+01    |proj g|=  4.46983D-01
#
# At iterate   10    f=  1.60459D+01    |proj g|=  2.12061D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f=  1.42133D+01    |proj g|=  7.20311D-04
#
# At iterate   20    f=  1.41652D+01    |proj g|=  1.04674D-04
#   ys=-3.301E+02  -gs= 7.259E-01 BFGS update SKIPPED
#
# At iterate   25    f=  8.98543D+00    |proj g|=  4.85394D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     27     48      1     1     0   8.062D-06   8.984D+00
#   F =   8.9841245108208732
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =2016.4438904238755
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.73043D+00    |proj g|=  8.13389D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     13      1     0     0   8.132D-04   9.730D+00
#   F =   9.7304289419152621
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =2183.6160829890187
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.66637D+02    |proj g|=  2.53585D+02
#
# At iterate    5    f=  5.59047D+02    |proj g|=  4.18189D+02
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# At iterate   10    f=  1.17531D+01    |proj g|=  2.16812D+01
#
# At iterate   15    f=  9.75659D+00    |proj g|=  5.48706D+00
#
# At iterate   20    f=  9.59174D+00    |proj g|=  3.64772D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     70      2     0     0   5.456D-04   9.592D+00
#   F =   9.5917059993775329
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =2154.542143860567
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.62656D+00    |proj g|=  1.04341D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     12      1     0     0   1.038D-05   8.627D+00
#   F =   8.6265554031380169
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =1652.7855744365477
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42649D+00    |proj g|=  4.13809D-01
#
# At iterate    5    f=  6.34875D+00    |proj g|=  1.41183D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7     10      1     0     0   1.197D-04   6.349D+00
#   F =   6.3487508298958977
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =1430.120185896681
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.16486D+00    |proj g|=  6.57987D+00
#
# At iterate    5    f=  7.16293D+00    |proj g|=  3.52989D-01
#
# At iterate   10    f=  7.07040D+00    |proj g|=  7.74546D-02
#
# At iterate   15    f=  7.07027D+00    |proj g|=  1.73169D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     21      1     0     0   1.732D-05   7.070D+00
#   F =   7.0702713068733871
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =1591.7407727396387
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.34148D+00    |proj g|=  7.47811D-01
#
# At iterate    5    f=  6.99764D+00    |proj g|=  3.28394D-02
#
# At iterate   10    f=  6.99746D+00    |proj g|=  5.58295D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     11     15      1     0     0   1.837D-05   6.997D+00
#   F =   6.9974600316828770
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =1577.4310470969644
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.26205D+00    |proj g|=  4.17600D+00
#
# At iterate    5    f=  6.51110D+00    |proj g|=  8.61292D-02
#
# At iterate   10    f=  6.46173D+00    |proj g|=  2.49545D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     21      1     0     0   6.274D-06   6.461D+00
#   F =   6.4614281874067236
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =1455.359913979106
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.57025D+00    |proj g|=  6.49412D+00
#
# At iterate    5    f=  6.40126D+00    |proj g|=  2.44188D-01
#
# At iterate   10    f=  6.33497D+00    |proj g|=  1.56754D-01
#
# At iterate   15    f=  6.32700D+00    |proj g|=  5.49381D-03
#
# At iterate   20    f=  6.32698D+00    |proj g|=  1.17917D-03
#  This problem is unconstrained.
# At iterate   25    f=  6.32688D+00    |proj g|=  8.53440D-02
#
# At iterate   30    f=  6.32029D+00    |proj g|=  2.42805D-01
#
# At iterate   35    f=  6.31483D+00    |proj g|=  4.10618D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     38     45      1     0     0   9.481D-06   6.315D+00
#   F =   6.3148169261728855
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =1424.5189914627263
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic       1424.518991
# Name: 63, dtype: object
#           pdq           pdqs          aic
# 0   (0, 0, 0)  (0, 0, 0, 12)  3017.609792
# 1   (0, 0, 0)  (0, 0, 1, 12)  2643.081730
# 2   (0, 0, 0)  (0, 1, 0, 12)  2280.370889
# 3   (0, 0, 0)  (0, 1, 1, 12)  2016.443890
# 4   (0, 0, 0)  (1, 0, 0, 12)  2183.616083
# ..        ...            ...          ...
# 59  (1, 1, 1)  (0, 1, 1, 12)  1430.120186
# 60  (1, 1, 1)  (1, 0, 0, 12)  1591.740773
# 61  (1, 1, 1)  (1, 0, 1, 12)  1577.431047
# 62  (1, 1, 1)  (1, 1, 0, 12)  1455.359914
# 63  (1, 1, 1)  (1, 1, 1, 12)  1424.518991
#
# [64 rows x 3 columns]

# %%
pdq= (1,1,1) 
pdqs=(1,1,1,12)
train,test,results = model_fit(ts_78721,pdq=pdq,pdqs=pdqs)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.63060D+01    |proj g|=  1.34624D+01
#
# At iterate    5    f=  8.20676D+00    |proj g|=  2.07185D-02
#
# At iterate   10    f=  8.20426D+00    |proj g|=  3.24111D-01
#
# At iterate   15    f=  8.19846D+00    |proj g|=  4.33220D-02
#
# At iterate   20    f=  8.19255D+00    |proj g|=  6.20316D-01
#
# At iterate   25    f=  8.17689D+00    |proj g|=  4.31698D-02
#
# At iterate   30    f=  8.17673D+00    |proj g|=  1.49277D-03
#
# At iterate   35    f=  8.17669D+00    |proj g|=  8.62373D-03
#
# At iterate   40    f=  8.17534D+00    |proj g|=  2.08507D-01
#
# At iterate   45    f=  8.04570D+00    |proj g|=  2.02180D-01
#
# At iterate   50    f=  7.81773D+00    |proj g|=  2.96612D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     57      1     0     0   2.966D-02   7.818D+00
#   F =   7.8177303175787634
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              78721   No. Observations:                  101
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -789.591
# Date:                            Sun, 16 Oct 2022   AIC                           1589.182
# Time:                                    16:44:09   BIC                           1601.568
# Sample:                                01-01-2009   HQIC                          1594.172
#                                      - 05-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9227      2.121     -0.435      0.663      -5.079       3.234
# ma.L1          0.9214      2.125      0.434      0.665      -3.243       5.086
# ar.S.L12       0.9997      0.197      5.087      0.000       0.615       1.385
# ma.S.L12      -0.9999      0.266     -3.752      0.000      -1.522      -0.478
# sigma2       3.65e+06   1.83e-07   1.99e+13      0.000    3.65e+06    3.65e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  54.00   Jarque-Bera (JB):                11.33
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.97   Skew:                            -0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.06e+30. Standard errors may be unstable.

# %%
train_model(train,results)
# Out:
# SARIMA model RMSE on train data: 3105.46039

# %%
test_model(ts_78721,pdq=pdq, pdqs=pdqs)
# Out:
# SARIMA model RMSE on train data: 1155.21390

# %%
pdq = (1, 1, 1)
pdqs =(1, 1, 1, 12)
pred_78721 = forecast_model(ts_78721,pdq=pdq, pdqs=pdqs,zc=78721)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.36122D+01    |proj g|=  1.24015D+01
#
# At iterate    5    f=  8.30328D+00    |proj g|=  3.61061D-02
#
# At iterate   10    f=  8.29418D+00    |proj g|=  4.22355D-01
#
# At iterate   15    f=  8.28936D+00    |proj g|=  1.87378D-02
#
# At iterate   20    f=  8.28643D+00    |proj g|=  7.47973D-01
#  This problem is unconstrained.
# At iterate   25    f=  8.26137D+00    |proj g|=  8.16593D-02
#
# At iterate   30    f=  8.25800D+00    |proj g|=  8.69970D-03
#
# At iterate   35    f=  8.25498D+00    |proj g|=  9.60122D-02
#
# At iterate   40    f=  8.23870D+00    |proj g|=  1.40968D-01
#
# At iterate   45    f=  8.10540D+00    |proj g|=  2.52420D-01
#
# At iterate   50    f=  7.91671D+00    |proj g|=  1.32406D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     59      1     0     0   1.324D-02   7.917D+00
#   F =   7.9167080215899359
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Forecast property mean value at initial investment date 2017-05: 274349.6
# Forecast property mean value in 1 year: 310842.17 is 13.3 %ROI
# Forecast property mean value in 3 years: 381326.85 is 38.99 %ROI
# Forecast property mean value in 5 years: 448960.56 is 63.65 %ROI

# %%
# Add the 5 yr roi to the results summary df
df_zip_5YR_ROI.loc[df_zip_5YR_ROI['Zipcode'] == 78721, '5YR_PRED_ROI'] = 63.65
df_zip_5YR_ROI
# Out:
#    Zipcode  5_YR_PRED_ROI  5YR_PRED_ROI
# 0    78702              0         34.83
# 1    78758              0         84.89
# 2    78721              0         63.65
# 3    78723              0           NaN
# 4    78741              0           NaN

# %% [markdown]
# ### Zipcode 78723

# %%
AIC_PDQS(ts_78723)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.37514D+01    |proj g|=  1.26121D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.261D-08   1.375D+01
#   F =   13.751424702840371
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =3082.319133436243
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.
-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     54      1     0     0   1.080D-02   7.829D+00
#   F =   7.8286088811914230
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =1761.6083893868788
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.76251D+00    |proj g|=  1.05520D+00
#
# At iterate    5    f=  7.11370D+00    |proj g|=  2.38257D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     51      2     0     0   4.776D-05   7.094D+00
#   F =   7.0941554601190528
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =1595.0908230666678
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.65217D+01    |proj g|=  1.34319D+01
#
# At iterate    5    f=  1.07066D+01    |proj g|=  1.11508D+01
#
# At iterate   10    f=  9.87230D+00    |proj g|=  1.29865D+01
#
# At iterate   15    f=  9.03131D+00    |proj g|=  1.51869D-01
#
# At iterate   20    f=  9.02367D+00    |proj g|=  1.77604D-01
#  This problem is unconstrained.
# At iterate   25    f=  9.02255D+00    |proj g|=  8.15796D-04
#
# At iterate   30    f=  9.02131D+00    |proj g|=  3.25851D-02
#
# At iterate   35    f=  8.90700D+00    |proj g|=  1.42276D+00
#   ys=-1.494E+00  -gs= 4.935E-01 BFGS update SKIPPED
#
# At iterate   40    f=  7.10589D+00    |proj g|=  1.01319D-01
#
# At iterate   45    f=  7.10550D+00    |proj g|=  1.36414D-01
#
# At iterate   50    f=  7.10211D+00    |proj g|=  2.70834D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     79      1     1     0   2.708D-01   7.102D+00
#   F =   7.1021124336593244
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =1598.8731851396888
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.40978D+00    |proj g|=  5.65089D-01
#
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =1840.8620372074868At iterate    5    f=  8.19136D+00    |proj g|=  1.30662D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     17      1     0     0   3.832D-04   8.191D+00
#   F =   8.1913483803905667
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.70371D+00    |proj g|=  1.51465D+01
#
# At iterate    5    f=  8.38681D+00    |proj g|=  5.70289D-01
#
# At iterate   10    f=  8.37308D+00    |proj g|=  5.13919D-01
#
# At iterate   15    f=  8.02737D+00    |proj g|=  4.81658D+01
#
# At iterate   20    f=  7.60548D+00    |proj g|=  2.76613D+00
#
# At iterate   25    f=  7.60358D+00    |proj g|=  5.40159D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     25     39      1     0     0   5.402D-04   7.604D+00
#   F =   7.6035783008634414
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =1711.201539393411
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.31657D+01    |proj g|=  1.64533D+01
#
# At iterate    5    f=  8.44926D+00    |proj g|=  3.10529D-01
#
# At iterate   10    f=  8.43572D+00    |proj g|=  2.92100D-04
#
# At iterate   15    f=  8.43568D+00    |proj g|=  5.83601D-03
#
# At iterate   20    f=  8.43011D+00    |proj g|=  9.01631D-02
#
# At iterate   25    f=  8.23624D+00    |proj g|=  9.74704D-01
#
# At iterate   30    f=  7.96932D+00    |proj g|=  9.62199D-02
#
# At iterate   35    f=  7.95436D+00    |proj g|=  1.50919D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
# ...
#
# At iterate    0    f=  7.45483D+00    |proj g|=  1.72121D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     12      1     0     0   1.719D-05   7.455D+00
#   F =   7.4548336800457351
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =1673.8827443302446
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.07733D+01    |proj g|=  2.12299D+01
#
# At iterate    5    f=  6.54094D+00    |proj g|=  2.34742D-01
#
# At iterate   10    f=  6.53536D+00    |proj g|=  3.15556D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     13      1     0     0   3.156D-05   6.535D+00
#   F =   6.5353589760493973
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =1469.920410635065
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.01246D+00    |proj g|=  3.67174D+00
#
# At iterate    5    f=  6.78310D+00    |proj g|=  1.74633D-01
#
# At iterate   10    f=  6.77497D+00    |proj g|=  4.44140D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     12     13      1     0     0   7.057D-05   6.775D+00
#   F =   6.7749637425930391
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =1527.5918783408408
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.44712D+01    |proj g|=  2.90046D+01
#
# At iterate    5    f=  6.39936D+00    |proj g|=  3.54097D-01
#
# At iterate   10    f=  6.38931D+00    |proj g|=  5.68660D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     32      1     0     0   4.680D-05   6.389D+00
#   F =   6.3893132649318423
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =1439.2061713447326
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.19399D+01    |proj g|=  3.15431D+01
#
# At iterate    5    f=  6.31075D+00    |proj g|=  3.19721D-01
#
# At iterate   10    f=  6.27257D+00    |proj g|=  6.68790D-02
#
# At iterate   15    f=  6.27081D+00    |proj g|=  7.75202D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     16     19      1     0     0   7.751D-05   6.271D+00
#   F =   6.2708121769164746
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =1414.6619276292904
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic       1410.563246
# Name: 59, dtype: object
#           pdq           pdqs          aic
# 0   (0, 0, 0)  (0, 0, 0, 12)  3082.319133
# 1   (0, 0, 0)  (0, 0, 1, 12)  2698.343105
# 2   (0, 0, 0)  (0, 1, 0, 12)  2275.834284
# 3   (0, 0, 0)  (0, 1, 1, 12)  2012.685373
# 4   (0, 0, 0)  (1, 0, 0, 12)  2206.358155
# ..        ...            ...          ...
# 59  (1, 1, 1)  (0, 1, 1, 12)  1410.563246
# 60  (1, 1, 1)  (1, 0, 0, 12)  1550.848598
# 61  (1, 1, 1)  (1, 0, 1, 12)  1527.591878
# 62  (1, 1, 1)  (1, 1, 0, 12)  1439.206171
# 63  (1, 1, 1)  (1, 1, 1, 12)  1414.661928
#
# [64 rows x 3 columns]

# %%
pdq =(1, 1, 1)
pdqs =(0, 1, 1, 12)
train,test,results= model_fit(ts_78723,pdq=pdq,pdqs=pdqs)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.04431D+01    |proj g|=  1.05202D+01
#
# At iterate    5    f=  9.44569D+00    |proj g|=  1.05304D-01
#
# At iterate   10    f=  9.39262D+00    |proj g|=  1.42885D+00
#
# At iterate   15    f=  9.35281D+00    |proj g|=  5.67665D-03
#
# At iterate   20    f=  9.35222D+00    |proj g|=  7.63964D-02
#
# At iterate   25    f=  9.10795D+00    |proj g|=  3.69615D+00
#
# At iterate   30    f=  8.04026D+00    |proj g|=  7.13579D-02
#
# At iterate   35    f=  8.02713D+00    |proj g|=  1.62323D-04
#
# At iterate   40    f=  8.02706D+00    |proj g|=  3.16614D-02
#
# At iterate   45    f=  8.02683D+00    |proj g|=  7.09950D-03
#
# At iterate   50    f=  8.02681D+00    |proj g|=  6.12061D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     64      1     0     0   6.121D-03   8.027D+00
#   F =   8.0268143810388608
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              78723   No. Observations:                  101
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -810.708
# Date:                            Sun, 16 Oct 2022   AIC                           1629.417
# Time:                                    17:04:04   BIC                           1639.326
# Sample:                                01-01-2009   HQIC                          1633.409
#                                      - 05-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999     33.238      0.030      0.976     -64.146      66.146
# ma.L1         -0.9999     33.314     -0.030      0.976     -66.294      64.295
# ma.S.L12      -0.0046      0.026     -0.176      0.860      -0.056       0.046
# sigma2      5.868e+06      0.001   4.73e+09      0.000    5.87e+06    5.87e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  68.03   Jarque-Bera (JB):                 0.00
# Prob(Q):                              0.00   Prob(JB):                         1.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.00
# Prob(H) (two-sided):                  0.87   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.43e+25. Standard errors may be unstable.

# %%
train_model(train,results)
# Out:
# SARIMA model RMSE on train data: 2111.23885

# %%
test_model(ts_78723,pdq=pdq,pdqs=pdqs)
# Out:
# SARIMA model RMSE on train data: 1071.15523

# %%
pred_78723 = forecast_model(ts_78723,pdq=pdq,pdqs=pdqs,zc=78723)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.64169D+01    |proj g|=  1.03347D+01
#
# At iterate    5    f=  9.43871D+00    |proj g|=  8.86867D-02
#
# At iterate   10    f=  9.38803D+00    |proj g|=  2.65350D+00
#  This problem is unconstrained.
# At iterate   15    f=  9.31244D+00    |proj g|=  3.63308D-03
#
# At iterate   20    f=  9.31225D+00    |proj g|=  7.38889D-02
#
# At iterate   25    f=  9.28875D+00    |proj g|=  5.29289D-01
#
# At iterate   30    f=  8.13239D+00    |proj g|=  7.86370D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     34     43      1     0     0   1.066D-04   8.132D+00
#   F =   8.1318980217750170
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Forecast property mean value at initial investment date 2017-05: 333285.63
# Forecast property mean value in 1 year: 357732.71 is 7.34 %ROI
# Forecast property mean value in 3 years: 406628.32 is 22.01 %ROI
# Forecast property mean value in 5 years: 455525.84 is 36.68 %ROI

# %%
# Add the 5 yr roi to the results summary df
df_zip_5YR_ROI.loc[df_zip_5YR_ROI['Zipcode'] == 78723, '5YR_PRED_ROI'] = 36.68
df_zip_5YR_ROI
# Out:
#    Zipcode  5_YR_PRED_ROI  5YR_PRED_ROI
# 0    78702              0         34.83
# 1    78758              0         84.89
# 2    78721              0         63.65
# 3    78723              0         36.68
# 4    78741              0           NaN

# %% [markdown]
# ### Zipcode 78741

# %%
AIC_PDQS(ts_78741)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.33503D+01    |proj g|=  1.54543D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.545D-08   1.335D+01
#   F =   13.350329206414203
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =2992.4737422367816
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.41043D+02    |proj g|=  8.82319D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4     11      1     0     0   4.699D-06   1.166D+01
#   F =   11.664645629453590
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =2616.880620997604
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.85535D+00    |proj g|=  7.30918D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   7.309D-06   9.855D+00
#   F =   9.8553539910548942
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =2209.599293996296
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.53724D+02    |proj g|=  2.17860D+01
#
# At iterate    5    f=  3.71952D+01    |proj g|=  7.81985D-01
#
# At iterate   10    f=  1.59229D+01    |proj g|=  3.69737D-02
#
# At iterate   15    f=  1.37075D+01    |proj g|=  1.33845D-03
#
# At iterate   20    f=  1.36390D+01    |proj g|=  1.11033D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   25    f=  1.05562D+01    |proj g|=  3.07106D-03
#   ys=-4.667E+01  -gs= 5.945E-01 BFGS update SKIPPED
#   ys=-2.418E+00  -gs= 7.181E-01 BFGS update SKIPPED
#
# At iterate   30    f=  8.70663D+00    |proj g|=  2.96387D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     31     62      1     2     0   3.865D-07   8.707D+00
#   F =   8.7066334912709635
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =1954.2859020446958
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.59536D+00    |proj g|=  9.22960D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     15      1     0     0   9.229D-04   9.595D+00
#   F =   9.5953590496974837
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =2153.3604271322365
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00855D+03    |proj g|=  2.99901D+02
#
# At iterate    5    f=  5.69145D+02    |proj g|=  2.91183D+02
#
# At iterate   10    f=  1.21248D+01    |proj g|=  1.31294D+01
#
# At iterate   15    f=  9.46106D+00    |proj g|=  4.13070D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =1919.1905145694648
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.51573D+00    |proj g|=  1.06212D+01
#
# At iterate    5    f=  8.89569D+00    |proj g|=  4.12418D+01
#
# At iterate   10    f=  7.62054D+00    |proj g|=  9.32753D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     30      1     0     0   1.063D-05   7.621D+00
#   F =   7.6205414593986882
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =1713.0012869053062
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.87285D+00    |proj g|=  3.81269D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     15      1     0     0   3.811D-04   7.873D+00
#   F =   7.8728452954209649
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =1767.517346174296
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95072D+00    |proj g|=  2.67196D+00
#
# At iterate    5    f=  9.85158D+00    |proj g|=  1.30854D+00
#
# At iterate   10    f=  9.26335D+00    |proj g|=  8.08877D-01
#
# At iterate   15    f=  9.21811D+00    |proj g|=  3.32649D-02
#
# At iterate   20    f=  9.21806D+00    |proj g|=  8.32319D-03
#
# At iterate   25    f=  9.21753D+00    |proj g|=  1.15102D-01
#
# At iterate   30    f=  9.15249D+00    |proj g|=  9.33633D-01
#  This problem is unconstrained.
# At iterate   35    f=  8.19420D+00    |proj g|=  2.17313D+00
#
# At iterate   40    f=  6.96808D+00    |proj g|=  5.41947D-04
#
# At iterate   45    f=  6.96783D+00    |proj g|=  1.10355D-01
#
# At iterate   50    f=  6.96713D+00    |proj g|=  3.92649D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     77      1     0     0   3.926D-02   6.967D+00
#   F =   6.9671340155884307
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =1566.6380194918086
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.01489D+00    |proj g|=  1.71892D+00
#
# At iterate    5    f=  7.69733D+00    |proj g|=  8.09910D+00
#
# At iterate   10    f=  7.61840D+00    |proj g|=  6.00237D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     33      1     0     0   4.311D-05   7.618D+00
#   F =   7.6183983788507650
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =1712.5212368625714
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.15167D+01    |proj g|=  1.44045D+02
#
# At iterate    5    f=  8.74921D+00    |proj g|=  2.83765D-01
#
# At iterate   10    f=  8.74155D+00    |proj g|=  1.73570D+00
#
# At iterate   15    f=  8.24764D+00    |proj g|=  1.60709D+01
#
# At iterate   20    f=  7.75909D+00    |proj g|=  2.41930D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     34      1     0     0   1.882D-04   7.759D+00
#   F =   7.7590827761880155
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =1746.0345418661154
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.32069D+00    |proj g|=  9.05151D-01
#
# At iterate    5    f=  6.99353D+00    |proj g|=  2.02433D+00
#
# At iterate   10    f=  6.85068D+00    |proj g|=  6.38236D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     17      1     0     0   7.603D-05   6.851D+00
#   F =   6.8506674856898888
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =1540.549516794535
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.33818D+01    |proj g|=  3.58103D+00
#
# At iterate    5    f=  8.75410D+00    |proj g|=  2.23442D-01
#
# At iterate   10    f=  8.44352D+00    |proj g|=  6.19733D-01
#
# At iterate   15    f=  8.27463D+00    |proj g|=  2.96951D+00
#
# At iterate   20    f=  7.99383D+00    |proj g|=  4.73957D+00
#  This problem is unconstrained.
# At iterate   25    f=  6.91208D+00    |proj g|=  1.41399D+00
#
# At iterate   30    f=  6.88742D+00    |proj g|=  7.30890D-01
#
# At iterate   35    f=  6.85013D+00    |proj g|=  5.01921D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     38     65      1     0     0   7.684D-05   6.850D+00
#   F =   6.8501268550860122
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =1542.4284155392668
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.10951D+00    |proj g|=  5.30195D-01
#
# At iterate    5    f=  8.02232D+00    |proj g|=  7.07359D-01
#
#            * * *
#
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated
-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      9     12      1     0     0   6.957D-05   6.829D+00
#   F =   6.8289888835751942
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =1537.6935099208436
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.36266D+00    |proj g|=  1.18451D+01
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  7.25164D+00    |proj g|=  6.61027D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     11      1     0     0   1.595D-04   7.250D+00
#   F =   7.2502020291666458
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =1630.0452545333287
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.89444D+00    |proj g|=  3.81557D+00
#
# At iterate    5    f=  6.26211D+00    |proj g|=  3.36092D-02
#  This problem is unconstrained.
# At iterate   10    f=  6.26177D+00    |proj g|=  2.09544D-04
#
# At iterate   15    f=  6.26173D+00    |proj g|=  7.94810D-03
#
# At iterate   20    f=  6.25964D+00    |proj g|=  3.81269D-02
#
# At iterate   25    f=  6.25885D+00    |proj g|=  3.17560D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     26     30      1     0     0   9.632D-07   6.259D+00
#   F =   6.2588505723168995
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =1409.9825281989854
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.77344D+00    |proj g|=  5.80340D+00
#
# At iterate    5    f=  6.92083D+00    |proj g|=  7.90496D-01
#
# At iterate   10    f=  6.90989D+00    |proj g|=  3.44178D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     20      1     0     0   2.580D-05   6.910D+00
#   F =   6.9098816371489660
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =1555.8134867213685
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.10740D+00    |proj g|=  7.04452D-01
#
# At iterate    5    f=  6.81484D+00    |proj g|=  2.12543D-02
#
# At iterate   10    f=  6.81457D+00    |proj g|=  9.40026D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     10     13      1     0     0   9.400D-05   6.815D+00
#   F =   6.8145735178654743
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =1536.4644680018662
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.06734D+01    |proj g|=  1.59410D+01
#
# At iterate    5    f=  6.40952D+00    |proj g|=  1.39670D-01
#
# At iterate   10    f=  6.40237D+00    |proj g|=  3.15606D-04
#
# At iterate   15    f=  6.40236D+00    |proj g|=  1.90138D-03
#
# At iterate   20    f=  6.40227D+00    |proj g|=  2.44800D-02
#
# At iterate   25    f=  6.40010D+00    |proj g|=  7.08020D-02
#
# At iterate   30    f=  6.39939D+00    |proj g|=  2.29078D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     35      1     0     0   2.888D-06   6.399D+00
#   F =   6.3993891459524077
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =1441.4631686933394
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.22935D+00    |proj g|=  1.18402D+01
#
# At iterate    5    f=  6.31131D+00    |proj g|=  2.01995D-01
#
# At iterate   10    f=  6.28824D+00    |proj g|=  1.52048D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     14     16      1     0     0   9.095D-06   6.288D+00
#   F =   6.2879243376315417
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =1418.4950516294653
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic       1409.982528
# Name: 59, dtype: object
#           pdq           pdqs          aic
# 0   (0, 0, 0)  (0, 0, 0, 12)  2992.473742
# 1   (0, 0, 0)  (0, 0, 1, 12)  2616.880621
# 2   (0, 0, 0)  (0, 1, 0, 12)  2209.599294
# 3   (0, 0, 0)  (0, 1, 1, 12)  1954.285902
# 4   (0, 0, 0)  (1, 0, 0, 12)  2153.360427
# ..        ...            ...          ...
# 59  (1, 1, 1)  (0, 1, 1, 12)  1409.982528
# 60  (1, 1, 1)  (1, 0, 0, 12)  1555.813487
# 61  (1, 1, 1)  (1, 0, 1, 12)  1536.464468
# 62  (1, 1, 1)  (1, 1, 0, 12)  1441.463169
# 63  (1, 1, 1)  (1, 1, 1, 12)  1418.495052
#
# [64 rows x 3 columns]

# %%
pdq =(1, 1, 1)
pdqs =(0, 1, 1, 12)
train,test,results= model_fit(ts_78741,pdq=pdq,pdqs=pdqs)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.45479D+01    |proj g|=  1.62137D+01
#
# At iterate    5    f=  7.78487D+00    |proj g|=  1.75494D-02
#
# At iterate   10    f=  7.78137D+00    |proj g|=  3.34570D-01
#
# At iterate   15    f=  7.77355D+00    |proj g|=  1.23192D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     20      1     0     0   2.371D-03   7.774D+00
#   F =   7.7735454442373060
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              78741   No. Observations:                  101
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -785.128
# Date:                            Sun, 16 Oct 2022   AIC                           1578.256
# Time:                                    17:04:43   BIC                           1588.166
# Sample:                                01-01-2009   HQIC                          1582.248
#                                      - 05-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3090      0.207      1.491      0.136      -0.097       0.715
# ma.L1         -0.2643      0.208     -1.268      0.205      -0.673       0.144
# ma.S.L12       0.0015      0.043      0.034      0.973      -0.082       0.085
# sigma2      4.564e+05   1.91e+04     23.925      0.000    4.19e+05    4.94e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  43.41   Jarque-Bera (JB):                 6.42
# Prob(Q):                              0.00   Prob(JB):                         0.04
# Heteroskedasticity (H):               4.59   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
train_model(train,results)
# Out:
# SARIMA model RMSE on train data: 2114.13075

# %%
test_model(ts_78741,pdq=pdq,pdqs=pdqs)
# Out:
# SARIMA model RMSE on train data: 1824.55694

# %%
pred_78741 = forecast_model(ts_78741,pdq=pdq,pdqs=pdqs,zc=78741)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.12006D+01    |proj g|=  9.25939D+00
#
# At iterate    5    f=  8.38287D+00    |proj g|=  8.48742D-02
#
# At iterate   10    f=  8.38027D+00    |proj g|=  3.66610D-01
#
# At iterate   15    f=  8.35874D+00    |proj g|=  8.04272D-03
#
# At iterate   20    f=  8.35864D+00    |proj g|=  5.48287D-02
#
# At iterate   25    f=  8.34740D+00    |proj g|=  7.45752D-01
#
# At iterate   30    f=  8.01148D+00    |proj g|=  2.10216D+00
#
# At iterate   35    f=  7.86615D+00    |proj g|=  3.38064D-02
#
# At iterate   40    f=  7.86610D+00    |proj g|=  2.00928D-02
#
# At iterate   45    f=  7.86568D+00    |proj g|=  7.67666D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     49     64      1     0     0   2.906D-04   7.865D+00
#   F =   7.8654919135658039
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Forecast property mean value at initial investment date 2017-05: 230792.82
# Forecast property mean value in 1 year: 255889.44 is 10.87 %ROI
# Forecast property mean value in 3 years: 306083.43 is 32.62 %ROI
# Forecast property mean value in 5 years: 356277.41 is 54.37 %ROI

# %%
# Add the 5 yr roi to the results summary df
df_zip_5YR_ROI.loc[df_zip_5YR_ROI['Zipcode'] == 78741, '5YR_PRED_ROI'] = 54.327
df_zip_5YR_ROI
# Out:
#    Zipcode  5_YR_PRED_ROI  5YR_PRED_ROI
# 0    78702              0        34.830
# 1    78758              0        84.890
# 2    78721              0        63.650
# 3    78723              0        36.680
# 4    78741              0        54.327

# %%
zipcode = ['78702','78758','78721','78723','78741']
zipselect_5yr_ROI = [34.83,84.89,63.65,36.68,54.33]
clrs=['green' if (value < max(zipselect_5yr_ROI)) else 'orange' for value in zipselect_5yr_ROI]
plt.bar(zipcode, zipselect_5yr_ROI,color=clrs)
plt.title('5 Year Prediction ROI from 2017-04')
plt.xlabel('Zipcode')
plt.ylabel('5 Year Prediction of ROI %')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# According to the 5 year ROI projection, zipcode 78758 has the highest ROI.

# %% [markdown]
# # Furthermore
